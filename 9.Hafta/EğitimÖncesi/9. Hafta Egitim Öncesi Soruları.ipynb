# %% [markdown]
# # Problem 1
# Vehicle sınıfından miras alan bir Bus sınıfı oluşturun. Bus.seating_capacity()'nin kapasite bağımsız değişkenine varsayılan olarak 50 değerini verin.
#
# ```
# Output:
# > The seating capacity of a bus is 50 passengers
# ```

# %%
# 1.Problemin Çözümünü Buraya Yazınız
class Bus:
    def __init__(self, model, speed, year ):
        self.speed = speed
        self.model = model
        self.year = year

def seating_capacity(self, capacity=50):
        return f"The seating capacity of a bus is 50 passengers."

myBus = Bus("Mercedes", "Sprinter", 2021)
print(myBus.seating_capacity()) # Bu otobüsün oturma kapasitesi 50 yolcudur.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 12
#       9         return f"The seating capacity of a bus is 50 passengers."
#      11 myBus = Bus("Mercedes", "Sprinter", 2021)
# ---> 12 print(myBus.seating_capacity()) # Bu otobüsün oturma kapasitesi 50 yolcudur.
#
# AttributeError: 'Bus' object has no attribute 'seating_capacity'

# %%
# Out:
# This bus has a seating capacity of 50 passengers.
# This bus has a seating capacity of 30 passengers.

# %% [markdown]
# # Problem 2
#
#
# School_bus'ın aynı zamanda Vehicle sınıfının bir örneği olup olmadığını belirleyiniz.

# %%
# 2.Problemin Çözümünü Buraya Yazınız.
